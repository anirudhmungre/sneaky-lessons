# %%
# %matplotlib
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
# Out:
# Using matplotlib backend: MacOSX

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=5000, centers=2, n_features=2, random_state=42, cluster_std=3)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 15
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Train on 3750 samples
# Epoch 1/50
# 3750/3750 [==============================] - 1s 231us/sample - loss: 0.7540 - accuracy: 0.3680
# Epoch 2/50
# 3750/3750 [==============================] - 0s 40us/sample - loss: 0.5384 - accuracy: 0.9280
# Epoch 3/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.4044 - accuracy: 0.9451
# Epoch 4/50
# 3750/3750 [==============================] - 0s 45us/sample - loss: 0.3166 - accuracy: 0.9453
# Epoch 5/50
# 3750/3750 [==============================] - 0s 49us/sample - loss: 0.2578 - accuracy: 0.9456
# Epoch 6/50
# 3750/3750 [==============================] - 0s 49us/sample - loss: 0.2181 - accuracy: 0.9456
# Epoch 7/50
# 3750/3750 [==============================] - 0s 48us/sample - loss: 0.1910 - accuracy: 0.9464
# Epoch 8/50
# 3750/3750 [==============================] - 0s 48us/sample - loss: 0.1722 - accuracy: 0.9469
# Epoch 9/50
# 3750/3750 [==============================] - 0s 40us/sample - loss: 0.1590 - accuracy: 0.9475
# Epoch 10/50
# 3750/3750 [==============================] - 0s 45us/sample - loss: 0.1494 - accuracy: 0.9464
# Epoch 11/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1425 - accuracy: 0.9483
# Epoch 12/50
# 3750/3750 [==============================] - 0s 40us/sample - loss: 0.1375 - accuracy: 0.9491
# Epoch 13/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1338 - accuracy: 0.9488
# Epoch 14/50
# 3750/3750 [==============================] - 0s 40us/sample - loss: 0.1310 - accuracy: 0.9493
# Epoch 15/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1290 - accuracy: 0.9491
# Epoch 16/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1276 - accuracy: 0.9501
# Epoch 17/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1265 - accuracy: 0.9496
# Epoch 18/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1255 - accuracy: 0.9499
# Epoch 19/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1249 - accuracy: 0.9501
# Epoch 20/50
# 3750/3750 [==============================] - 0s 52us/sample - loss: 0.1244 - accuracy: 0.9504
# Epoch 21/50
# 3750/3750 [==============================] - 0s 52us/sample - loss: 0.1241 - accuracy: 0.9504
# Epoch 22/50
# 3750/3750 [==============================] - 0s 48us/sample - loss: 0.1238 - accuracy: 0.9507
# Epoch 23/50
# 3750/3750 [==============================] - 0s 49us/sample - loss: 0.1236 - accuracy: 0.9499
# Epoch 24/50
# 3750/3750 [==============================] - 0s 46us/sample - loss: 0.1234 - accuracy: 0.9504
# Epoch 25/50
# 3750/3750 [==============================] - 0s 40us/sample - loss: 0.1233 - accuracy: 0.9509
# Epoch 26/50
# 3750/3750 [==============================] - 0s 44us/sample - loss: 0.1233 - accuracy: 0.9504
# Epoch 27/50
# 3750/3750 [==============================] - 0s 42us/sample - loss: 0.1232 - accuracy: 0.9501
# Epoch 28/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1232 - accuracy: 0.9504
# Epoch 29/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1231 - accuracy: 0.9509
# Epoch 30/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1231 - accuracy: 0.9509
# Epoch 31/50
# 3750/3750 [==============================] - 0s 47us/sample - loss: 0.1231 - accuracy: 0.9504
# Epoch 32/50
# 3750/3750 [==============================] - 0s 46us/sample - loss: 0.1231 - accuracy: 0.9501
# Epoch 33/50
# 3750/3750 [==============================] - 0s 41us/sample - loss: 0.1231 - accuracy: 0.9507
# Epoch 34/50
# 3750/3750 [==============================] - 0s 49us/sample - loss: 0.1231 - accuracy: 0.9496
# Epoch 35/50
# 3750/3750 [==============================] - 0s 51us/sample - loss: 0.1231 - accuracy: 0.9512
# Epoch 36/50
# 3750/3750 [==============================] - 0s 47us/sample - loss: 0.1231 - accuracy: 0.9504
# Epoch 37/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1230 - accuracy: 0.9499
# Epoch 38/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1231 - accuracy: 0.9501
# Epoch 39/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1230 - accuracy: 0.9504
# Epoch 40/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1231 - accuracy: 0.9509
# Epoch 41/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1230 - accuracy: 0.9507
# Epoch 42/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1231 - accuracy: 0.9499
# Epoch 43/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1230 - accuracy: 0.9501
# Epoch 44/50
# 3750/3750 [==============================] - 0s 37us/sample - loss: 0.1231 - accuracy: 0.9501
# Epoch 45/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1230 - accuracy: 0.9504
# Epoch 46/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1230 - accuracy: 0.9501
# Epoch 47/50
# 3750/3750 [==============================] - 0s 39us/sample - loss: 0.1230 - accuracy: 0.9504
# Epoch 48/50
# 3750/3750 [==============================] - 0s 38us/sample - loss: 0.1231 - accuracy: 0.9512
# Epoch 49/50
# 3750/3750 [==============================] - 0s 41us/sample - loss: 0.1229 - accuracy: 0.9496
# Epoch 50/50
# 3750/3750 [==============================] - 0s 47us/sample - loss: 0.1230 - accuracy: 0.9499

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1250/1 - 0s - loss: 0.0734 - accuracy: 0.9520
# Loss: 0.12402847929894924, Accuracy: 0.9520000219345093

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
