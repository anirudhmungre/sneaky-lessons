# %% [markdown]
# # Instructor Do: Create and Deploy a Machine Learning Model in Amazon SageMaker

# %%
# Initial imports
import os
import io
import json
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Amazon SageMaker and related imports
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3  # AWS Python sdk

# %matplotlib inline

# %% [markdown]
# ## Reading Data

# %%
# Read the weather features data
file_path = Path("Data/x_austin_final.csv")
features = pd.read_csv(file_path)

# Transforming the "TempAvgF" column to a vector
X = features["TempAvgF"].values.reshape(-1, 1)

# %%
# Read the target data (precipitation sum inches)
file_path = Path("Data/y_austin_final.csv")
y = pd.read_csv(file_path, names=["PrecipitationSumInches"], header=None)

# Transforming y into a vector
y = y.iloc[:, 0].values

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Creating the Linear Regression Model
#
# ### Initial Configurations

# %%
# Define Amazon S3 Bucket to store model data
bucket = "sagemaker-20200312-1736"  #'<your_s3_bucket_name_here>'

# Define prefix for data files
prefix = "austin-rainfall-regression"

# AWS IAM role
role = get_execution_role()

# %% [markdown]
# ### Uploading Training Data to Amazon S3

# %%
# Encode the training data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_train).astype("float32")
labels = np.array(y_train).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded training data to Amazon S3
key = "linear_train.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "train", key)
).upload_fileobj(buf)
s3_train_data = "s3://{}/{}/train/{}".format(bucket, prefix, key)
print("Training data uploaded to: {}".format(s3_train_data))
# Out:
# Training data uploaded to: s3://sagemaker-20200312-1736/austin-rainfall-regression/train/linear_train.data

# %% [markdown]
# ### Upload Test Data to Amazon S3

# %%
# Encode the testing data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_test).astype("float32")
labels = np.array(y_test).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded testing data to Amazon S3
key = "linear_test.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "test", key)
).upload_fileobj(buf)
s3_test_data = "s3://{}/{}/test/{}".format(bucket, prefix, key)
print("Testing data uploaded to: {}".format(s3_test_data))
# Out:
# Testing data uploaded to: s3://sagemaker-20200312-1736/austin-rainfall-regression/test/linear_test.data

# %% [markdown]
# ### Creating Model Instance

# %%
# Create an instance of the linear learner algorithm
container = get_image_uri(boto3.Session().region_name, "linear-learner")

# %%
# Start the Amazon SageMaker session
sess = sagemaker.Session()

# Create an instance of the linear learner estimator
linear = sagemaker.estimator.Estimator(
    container,
    role,
    train_instance_count=1,
    train_instance_type="ml.m4.xlarge",
    output_path="s3://{}/{}/output".format(bucket, prefix),
    sagemaker_session=sess,
)

# Define linear learner hyperparameters
linear.set_hyperparameters(
    feature_dim=1,
    mini_batch_size=100,
    predictor_type="regressor",
    epochs=10,
    num_models=32,
    loss="absolute_loss",
)

# %% [markdown]
# ## Training the Machine Learning Model

# %%
# Fitting the linear learner model with the training data
linear.fit({"train": s3_train_data, "test": s3_test_data})
# Out:
# 2020-03-13 01:22:02 Starting - Starting the training job...
# 2020-03-13 01:22:03 Starting - Launching requested ML instances......
# 2020-03-13 01:23:05 Starting - Preparing the instances for training......
# 2020-03-13 01:24:31 Downloading - Downloading input data
# 2020-03-13 01:24:31 Training - Downloading the training image...
# 2020-03-13 01:25:02 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/13/2020 01:24:54 INFO 140423771481920] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2020 01:24:54 INFO 140423771481920] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'absolute_loss', u'mini_batch_size': u'100', u'predictor_type': u'regressor', u'epochs': u'10', u'feature_dim': u'1', u'num_models': u'32'}
# [03/13/2020 01:24:54 INFO 140423771481920] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'10', u'feature_dim': u'1', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'32', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'100', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'absolute_loss', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2020 01:24:54 WARNING 140423771481920] Loggers have already been setup.
# Process 1 is a worker.
# [03/13/2020 01:24:54 INFO 140423771481920] Using default worker.
# [2020-03-13 01:24:54.526] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-03-13 01:24:54.546] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 21, "num_examples": 1, "num_bytes": 4800}
# [03/13/2020 01:24:54 INFO 140423771481920] Create Store: local
# [2020-03-13 01:24:54.606] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 59, "num_examples": 11, "num_bytes": 50640}
# [03/13/2020 01:24:54 INFO 140423771481920] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb697d94c50>
# [03/13/2020 01:24:54 INFO 140423771481920] Scaling model computed with parameters:
#  {'stdev_weight':
# [14.122752]
# <NDArray 1 @cpu(0)>, 'stdev_label':
# [0.44867328]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [0.12229998]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [70.779]
# <NDArray 1 @cpu(0)>}
# [03/13/2020 01:24:54 INFO 140423771481920] nvidia-smi took: 0.0252621173859 secs to identify 0 gpus
# [03/13/2020 01:24:54 INFO 140423771481920] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 1155, "sum": 1155.0, "min": 1155}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1584062694.717639, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1584062694.717597}
#
# [2020-03-13 01:24:54.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 227, "num_examples": 11, "num_bytes": 50640}
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.35031494140625, "sum": 0.35031494140625, "min": 0.35031494140625}}, "EndTime": 1584062694.946148, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946054}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.34816554260253907, "sum": 0.34816554260253907, "min": 0.34816554260253907}}, "EndTime": 1584062694.946248, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946227}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3504798126220703, "sum": 0.3504798126220703, "min": 0.3504798126220703}}, "EndTime": 1584062694.946315, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946297}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.34792242240905763, "sum": 0.34792242240905763, "min": 0.34792242240905763}}, "EndTime": 1584062694.946377, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946358}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.646133098602295, "sum": 0.646133098602295, "min": 0.646133098602295}}, "EndTime": 1584062694.946441, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946424}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.6284612922668457, "sum": 0.6284612922668457, "min": 0.6284612922668457}}, "EndTime": 1584062694.946505, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946487}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.638562463760376, "sum": 0.638562463760376, "min": 0.638562463760376}}, "EndTime": 1584062694.946568, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.94655}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.6396393585205078, "sum": 0.6396393585205078, "min": 0.6396393585205078}}, "EndTime": 1584062694.946633, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946615}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.35688458442687987, "sum": 0.35688458442687987, "min": 0.35688458442687987}}, "EndTime": 1584062694.946697, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.94668}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.34850450706481934, "sum": 0.34850450706481934, "min": 0.34850450706481934}}, "EndTime": 1584062694.946764, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946746}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3490651569366455, "sum": 0.3490651569366455, "min": 0.3490651569366455}}, "EndTime": 1584062694.946831, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946814}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.3491475887298584, "sum": 0.3491475887298584, "min": 0.3491475887298584}}, "EndTime": 1584062694.946894, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.946876}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.6285197944641113, "sum": 0.6285197944641113, "min": 0.6285197944641113}}, "EndTime": 1584062694.946958, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.94694}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.642867244720459, "sum": 0.642867244720459, "min": 0.642867244720459}}, "EndTime": 1584062694.947023, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.947005}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.6325280170440674, "sum": 0.6325280170440674, "min": 0.6325280170440674}}, "EndTime": 1584062694.947086, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694.947069}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.6433060894012451, "sum": 0.6433060894012451, "min": 0.6433060894012451}}, "EndTime": 1584062694.94715, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1584062694
"Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.902665}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2738775205612183, "sum": 0.2738775205612183, "min": 0.2738775205612183}}, "EndTime": 1584062696.902745, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.902727}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.31205000877380373, "sum": 0.31205000877380373, "min": 0.31205000877380373}}, "EndTime": 1584062696.902813, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.902792}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.31610263633728025, "sum": 0.31610263633728025, "min": 0.31610263633728025}}, "EndTime": 1584062696.902886, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.902866}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.32235195541381834, "sum": 0.32235195541381834, "min": 0.32235195541381834}}, "EndTime": 1584062696.902958, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.902938}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.32784318351745606, "sum": 0.32784318351745606, "min": 0.32784318351745606}}, "EndTime": 1584062696.903027, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903008}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.27629334831237795, "sum": 0.27629334831237795, "min": 0.27629334831237795}}, "EndTime": 1584062696.903098, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903079}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.2752975378036499, "sum": 0.2752975378036499, "min": 0.2752975378036499}}, "EndTime": 1584062696.903171, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.90315}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.27376686477661133, "sum": 0.27376686477661133, "min": 0.27376686477661133}}, "EndTime": 1584062696.903241, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903222}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.274140887260437, "sum": 0.274140887260437, "min": 0.274140887260437}}, "EndTime": 1584062696.90331, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903292}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.34016410827636717, "sum": 0.34016410827636717, "min": 0.34016410827636717}}, "EndTime": 1584062696.903381, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903362}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.4344713935852051, "sum": 0.4344713935852051, "min": 0.4344713935852051}}, "EndTime": 1584062696.903452, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903433}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.32319482040405273, "sum": 0.32319482040405273, "min": 0.32319482040405273}}, "EndTime": 1584062696.903524, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903504}
#
# #metrics {"Metrics": {"train_absolute_loss_objective": {"count": 1, "max": 0.458491512298584, "sum": 0.458491512298584, "min": 0.458491512298584}}, "EndTime": 1584062696.903593, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.903574}
#
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, epoch=8, train absolute_loss_objective <loss>=0.275050443649
# [03/13/2020 01:24:56 INFO 140423771481920] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=absolute_loss_objective, value=0.273766864777
# [03/13/2020 01:24:56 INFO 140423771481920] Early stop condition met. Stopping training.
# [03/13/2020 01:24:56 INFO 140423771481920] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Total Batches Seen": {"count": 1, "max": 111, "sum": 111.0, "min": 111}, "Total Records Seen": {"count": 1, "max": 10650, "sum": 10650.0, "min": 10650}, "Max Records Seen Between Resets": {"count": 1, "max": 1055, "sum": 1055.0, "min": 1055}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1584062696.907357, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1584062696.601779}
#
# [03/13/2020 01:24:56 INFO 140423771481920] #throughput_metric: host=algo-1, train throughput=3450.64300625 records/second
# [03/13/2020 01:24:56 WARNING 140423771481920] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/13/2020 01:24:56 WARNING 140423771481920] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-03-13 01:24:56.909] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 1, "num_examples": 1, "num_bytes": 4800}
# [2020-03-13 01:24:56.931] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 18, "num_examples": 11, "num_bytes": 50640}
# [03/13/2020 01:24:56 INFO 140423771481920] #train_score (algo-1) : ('absolute_loss_objective', 0.12016365494208313)
# [03/13/2020 01:24:56 INFO 140423771481920] #train_score (algo-1) : ('mse', 0.20695481209958333)
# [03/13/2020 01:24:56 INFO 140423771481920] #train_score (algo-1) : ('absolute_loss', 0.12016365494208313)
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=0.120163654942
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, train mse <loss>=0.2069548121
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, train absolute_loss <loss>=0.120163654942
# [03/13/2020 01:24:56 INFO 140423771481920] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.01, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [03/13/2020 01:24:56 INFO 140423771481920] Saved checkpoint to "/tmp/tmpjK_yGk/mx-mod-0000.params"
# [2020-03-13 01:24:56.939] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 2413, "num_examples": 1, "num_bytes": 4800}
# [2020-03-13 01:24:56.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 5, "num_examples": 3, "num_bytes": 12672}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Batches Since Last Reset": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Number of Records Since Last Reset": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Max Records Seen Between Resets": {"count": 1, "max": 264, "sum": 264.0, "min": 264}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1584062696.946307, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1584062696.939762}
#
# [03/13/2020 01:24:56 INFO 140423771481920] #test_score (algo-1) : ('absolute_loss_objective', 0.0943332693793557)
# [03/13/2020 01:24:56 INFO 140423771481920] #test_score (algo-1) : ('mse', 0.1523438836589004)
# [03/13/2020 01:24:56 INFO 140423771481920] #test_score (algo-1) : ('absolute_loss', 0.0943332693793557)
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, test absolute_loss_objective <loss>=0.0943332693794
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, test mse <loss>=0.152343883659
# [03/13/2020 01:24:56 INFO 140423771481920] #quality_metric: host=algo-1, test absolute_loss <loss>=0.0943332693794
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2562.10994720459, "sum": 2562.10994720459, "min": 2562.10994720459}, "finalize.time": {"count": 1, "max": 25.573015213012695, "sum": 25.573015213012695, "min": 25.573015213012695}, "initialize.time": {"count": 1, "max": 190.4599666595459, "sum": 190.4599666595459, "min": 190.4599666595459}, "check_early_stopping.time": {"count": 9, "max": 1.3899803161621094, "sum": 6.714582443237305, "min": 0.22983551025390625}, "setuptime": {"count": 1, "max": 30.61699867248535, "sum": 30.61699867248535, "min": 30.61699867248535}, "update.time": {"count": 9, "max": 305.1950931549072, "sum": 2185.0342750549316, "min": 214.1110897064209}, "epochs": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1584062696.952665, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1584062694.524627}
#
#
# 2020-03-13 01:25:09 Completed - Training job completed
# Training seconds: 61
# Billable seconds: 61

# %% [markdown]
# ## Deploying the Model to Make Predictions

# %%
# An instance of the linear-learner predictor is created
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
# Out:
# ---------------------!

# %%
# Linear predictor configurations
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %%
# Making some predictions using the test data.
result = linear_predictor.predict(X_test)
y_predictions = np.array([r["score"] for r in result["predictions"]])
y_predictions[:5]
# Out:
# array([0.00143104, 0.0013747 , 0.00102257, 0.00124793, 0.00113525])

# %% [markdown]
# ## Model Evaluation

# %%
# Plotting predicted Vs. actual values
plt.plot(np.array(y_test), label="actual")
plt.plot(y_predictions, label="predict")
plt.legend()
plt.show()

# %%
# Calculating the RMSE and R2 scores
rmse = np.sqrt(mean_squared_error(y_test, y_predictions))
r2 = r2_score(y_test, y_predictions)

print("RMSE: {}".format(rmse))
print("R2 score: {}".format(r2))
# Out:
# RMSE: 0.3903125434954216
# R2 score: -0.05964426269418377

# %% [markdown]
# ## Delete Amazon SageMaker end-point

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
