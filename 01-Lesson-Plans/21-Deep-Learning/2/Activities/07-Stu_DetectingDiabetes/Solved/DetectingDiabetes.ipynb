# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.1/21-Deep-Learning/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome.values
X = diabetes_df.drop(columns="Outcome").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7718 - accuracy: 0.3662
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.5592
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6698 - accuracy: 0.6377
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.6730
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6235 - accuracy: 0.6946
# Epoch 6/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5951 - accuracy: 0.7192
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5690 - accuracy: 0.7436
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5610 - accuracy: 0.7230
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5303 - accuracy: 0.7716
# Epoch 10/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7751
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4923 - accuracy: 0.7909
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4881 - accuracy: 0.7728
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4641 - accuracy: 0.8039
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4792 - accuracy: 0.7650
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.8119
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4713 - accuracy: 0.7632
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4957 - accuracy: 0.7763
# Epoch 18/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.7920
# Epoch 19/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4638 - accuracy: 0.7900
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.7986
# Epoch 21/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.7924
# Epoch 22/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4297 - accuracy: 0.7941
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.8159
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7906
# Epoch 25/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8188
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4161 - accuracy: 0.7993
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.8315
# Epoch 28/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4404 - accuracy: 0.7892
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8162
# Epoch 30/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.7927
# Epoch 31/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.8068
# Epoch 32/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7748
# Epoch 33/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4321 - accuracy: 0.7895
# Epoch 34/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.8093
# Epoch 35/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.7815
# Epoch 36/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4413 - accuracy: 0.8005
# Epoch 37/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8009
# Epoch 38/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8189
# Epoch 39/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4292 - accuracy: 0.7873
# Epoch 40/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.8142
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4107 - accuracy: 0.7986
# Epoch 42/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4071 - accuracy: 0.7845
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.8114
# Epoch 44/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8219
# Epoch 45/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8150
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3763 - accuracy: 0.8337
# Epoch 47/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4248 - accuracy: 0.7902
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8207
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8100
# Epoch 50/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4033 - accuracy: 0.7941
# 6/6 - 0s - loss: 0.5061 - accuracy: 0.7396
# Loss: 0.5061206817626953, Accuracy: 0.7395833134651184
