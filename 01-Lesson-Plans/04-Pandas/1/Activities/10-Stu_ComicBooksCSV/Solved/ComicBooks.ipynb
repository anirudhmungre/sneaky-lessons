# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the comic_books_expanded.csv file path
csv_path = "Resources/comic_books_expanded.csv"

# Import the comic_books_expanded.csv file as a DataFrame
books_df = pd.read_csv(csv_path, encoding="utf-8")
# Check the special characters imported correctly
books_df.tail()
# Out:
#                  Title                                       Other titles  \
# 28687             مترو          Metro : a story of Cairo ; Mitrū. English
# 28688  丘の上の楽園. English  Oka no ue no rakuen. English ; The paradise on...
# 28689     信じられない変更ロボット  Incredible change-bots : more than just machin...
# 28690          喜欢我也没关系                          Xi huan wo ye mei guan xi
# 28691   幻猪TKG千禧年之章 : 糕          Huan zhu TKG qian xi nian zhi zhang : Gao
#
#        BL record ID Type of resource                            Content type  \
# 28687      16035283        Monograph                Language material ; Text
# 28688      14053922        Monograph                Language material ; Text
# 28689      14477800        Monograph                Language material ; Text
# 28690      19361604        Monograph  Language material ; Still image ; Text
# 28691      17159458        Monograph                Language material ; Text
#
#       Material type BNB number           ISBN            Name  \
# 28687        Volume        NaN  9780805094886  Shāfiʿī, Majdī
# 28688        Volume  GBB256201  9781569708354  Tenzen, Momoko
# 28689        Volume  GBA812828  9781891830914  Brown, Jeffrey
# 28690        Volume        NaN  9787222155145    Wang, Chacha
# 28691        Volume        NaN  9789810422134       Tan, Chub
#
#       Dates associated with name  ...                             Publisher  \
# 28687                        NaN  ...             Henry Holt ; Metropolitan
# 28688                        NaN  ...                     Digital Manga Pub
# 28689                      1975-  ...                 Top Shelf Productions
# 28690                        NaN  ...  Yunnan ren min chu ban she ; 云南人民出版社
# 28691                      1973-  ...          Feng yun chu ban she ; 风云出版社
#
#       Date of publication           Edition  \
# 28687                2012  1st U.S. edition
# 28688                2007               NaN
# 28689                2007               NaN
# 28690                2017    Di 1 ban ; 第1版
# 28691                2000               NaN
#
#                                     Physical description Dewey classification  \
# 28687                     95 pages, illustrations, 26 cm             741.5962
# 28688            162 pages, chiefly illustrations, 21 cm             741.5952
# 28689  approximately 150 pages, chiefly colour illust...             741.5973
# 28690             221 pages, colour illustrations, 19 cm             741.5951
# 28691  118 pages, chiefly illustrations, 15 cm ; 118页...           741.595957
#
#           BL shelfmark                                             Topics  \
# 28687    YP.2016.b.247  Bank robberies--Egypt--Comic books, strips, et...
# 28688  YK.2012.a.16349  Love--Comic books, strips, etc ; Gay men--Comi...
# 28689   YK.2008.a.2035                   Robots--Comic books, strips, etc
# 28690   CHI.2019.a.225  Seals (Animals)--Comic books, strips, etc ; Gr...
# 28691   YP.2019.a.3339  Swine--Comic books, strips, etc ; Singaporean ...
#
#                                                    Genre  Languages  \
# 28687                     Comic or graphic novel ; Novel    English
# 28688  Comic or graphic novel ; Novel ; Translations ...    English
# 28689   Comic or graphic novel ; Novel ; Science fiction    English
# 28690                             Comic or graphic novel    Chinese
# 28691                             Comic or graphic novel    Chinese
#
#                                                    Notes
# 28687                                                NaN
# 28688  Published in Manga format ; Translated from th...
# 28689                                                NaN
# 28690  Author's prefer 'Wang Cha Cha'--page [2] of cover
# 28691                                               封面书名
#
# [5 rows x 27 columns]

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "ISBN", "Title", "Other titles", "Name", "All names", 
# "Country of publication", "Place of publication", "Publisher", "Date of publication"
reduced_df = books_df[["ISBN", "Title", "Other titles", "Name", "All names", 
                       "Country of publication", "Place of publication", 
                       "Publisher", "Date of publication"]]
reduced_df.head()
# Out:
#             ISBN                                              Title  \
# 0  9780930193904    #$@&! : the official Lloyd Llewellyn collection
# 1  9780992664220  #WhatDoYouSee? : a graphic novel anthology of ...
# 2  9781302903299                                 #takebacktheshield
# 3  9781607065166       '68. Volume 1. Better run through the jungle
# 4  9781600107672                                   'Bots of science
#
#                                         Other titles              Name  \
# 0                Official Lloyd Llewellyn collection    Clowes, Daniel
# 1                                                NaN               NaN
# 2                                                NaN     Spencer, Nick
# 3                      Better run through the jungle     Kidwell, Mark
# 4  Trans formers ; Trans formers animated : bots ...  Bryant, Megan E.
#
#                                            All names  \
# 0                            Clowes, Daniel [person]
# 1        Fulfilling Lives (Programme) [organisation]
# 2                     Spencer, Nick, author [person]
# 3  Fotos, Jay [person] ; Jones, Nat, 1976- [perso...
# 4  Robbins, Robbie [person] ; Boo, 1981- [person]...
#
#                Country of publication          Place of publication  \
# 0  England ; United States of America  London ; Seattle, Washington
# 1                             England           Newcastle upon Tyne
# 2            United States of America                      New York
# 3            United States of America          Berkeley, California
# 4            United States of America         San Diego, California
#
#                     Publisher  Date of publication
# 0  Fantagraphics ; Turnaround                 1997
# 1               Roots & Wings                 2018
# 2            Marvel Worldwide                 2017
# 3                Image Comics                 2012
# 4                         NaN                 2010

# %%
# Rename the headers to be more explanatory
renamed_df = reduced_df.rename(columns={"Other titles": "Other Titles",
                                        "Name": "Author",
                                        "All names": "All Names",
                                        "Country of publication": "Country of Publication",
                                        "Place of publication": "Place of Publication",
                                        "Date of publication": "Publication Year", })
renamed_df.head()
# Out:
#             ISBN                                              Title  \
# 0  9780930193904    #$@&! : the official Lloyd Llewellyn collection
# 1  9780992664220  #WhatDoYouSee? : a graphic novel anthology of ...
# 2  9781302903299                                 #takebacktheshield
# 3  9781607065166       '68. Volume 1. Better run through the jungle
# 4  9781600107672                                   'Bots of science
#
#                                         Other Titles            Author  \
# 0                Official Lloyd Llewellyn collection    Clowes, Daniel
# 1                                                NaN               NaN
# 2                                                NaN     Spencer, Nick
# 3                      Better run through the jungle     Kidwell, Mark
# 4  Trans formers ; Trans formers animated : bots ...  Bryant, Megan E.
#
#                                            All Names  \
# 0                            Clowes, Daniel [person]
# 1        Fulfilling Lives (Programme) [organisation]
# 2                     Spencer, Nick, author [person]
# 3  Fotos, Jay [person] ; Jones, Nat, 1976- [perso...
# 4  Robbins, Robbie [person] ; Boo, 1981- [person]...
#
#                Country of Publication          Place of Publication  \
# 0  England ; United States of America  London ; Seattle, Washington
# 1                             England           Newcastle upon Tyne
# 2            United States of America                      New York
# 3            United States of America          Berkeley, California
# 4            United States of America         San Diego, California
#
#                     Publisher  Publication Year
# 0  Fantagraphics ; Turnaround              1997
# 1               Roots & Wings              2018
# 2            Marvel Worldwide              2017
# 3                Image Comics              2012
# 4                         NaN              2010

# %%
# Push the remade DataFrame to a new CSV file
renamed_df.to_csv("Output/books_clean.csv",
                  encoding="utf-8", index=False, header=True)
