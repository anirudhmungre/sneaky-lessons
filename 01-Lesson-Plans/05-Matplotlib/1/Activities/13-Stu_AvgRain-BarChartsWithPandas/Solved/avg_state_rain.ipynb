# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Millimetres
# 0      Alaska    43.2         1098
# 1     Alabama    58.9         1495
# 2    Arkansas    55.9         1421
# 3     Arizona    12.6          321
# 4  California    22.2          564

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,4))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x7fc9500d6340>,
#   <matplotlib.axis.XTick at 0x7fc9500d6310>,
#   <matplotlib.axis.XTick at 0x7fc9500bae20>,
#   <matplotlib.axis.XTick at 0x7fc982a13850>,
#   <matplotlib.axis.XTick at 0x7fc982a13d60>,
#   <matplotlib.axis.XTick at 0x7fc982a13430>,
#   <matplotlib.axis.XTick at 0x7fc982a26460>,
#   <matplotlib.axis.XTick at 0x7fc982a26970>,
#   <matplotlib.axis.XTick at 0x7fc982a26e80>,
#   <matplotlib.axis.XTick at 0x7fc982a2c3d0>,
#   <matplotlib.axis.XTick at 0x7fc982a2c8e0>,
#   <matplotlib.axis.XTick at 0x7fc982a2cdf0>,
#   <matplotlib.axis.XTick at 0x7fc982a31340>,
#   <matplotlib.axis.XTick at 0x7fc982a31850>,
#   <matplotlib.axis.XTick at 0x7fc982a2c460>,
#   <matplotlib.axis.XTick at 0x7fc982a264f0>,
#   <matplotlib.axis.XTick at 0x7fc982a31580>,
#   <matplotlib.axis.XTick at 0x7fc982a31d60>,
#   <matplotlib.axis.XTick at 0x7fc982a392b0>,
#   <matplotlib.axis.XTick at 0x7fc982a397c0>,
#   <matplotlib.axis.XTick at 0x7fc982a39cd0>,
#   <matplotlib.axis.XTick at 0x7fc982a40220>,
#   <matplotlib.axis.XTick at 0x7fc982a40730>,
#   <matplotlib.axis.XTick at 0x7fc982a39820>,
#   <matplotlib.axis.XTick at 0x7fc982a31490>,
#   <matplotlib.axis.XTick at 0x7fc982a407f0>,
#   <matplotlib.axis.XTick at 0x7fc982a40d60>,
#   <matplotlib.axis.XTick at 0x7fc982a462b0>,
#   <matplotlib.axis.XTick at 0x7fc982a467c0>,
#   <matplotlib.axis.XTick at 0x7fc982a46cd0>,
#   <matplotlib.axis.XTick at 0x7fc982a4b220>,
#   <matplotlib.axis.XTick at 0x7fc982a4b730>,
#   <matplotlib.axis.XTick at 0x7fc982a46a00>,
#   <matplotlib.axis.XTick at 0x7fc982a402e0>,
#   <matplotlib.axis.XTick at 0x7fc982a4ba90>,
#   <matplotlib.axis.XTick at 0x7fc982a4be20>,
#   <matplotlib.axis.XTick at 0x7fc982a54370>,
#   <matplotlib.axis.XTick at 0x7fc982a54880>,
#   <matplotlib.axis.XTick at 0x7fc982a54d90>,
#   <matplotlib.axis.XTick at 0x7fc982a5a2e0>,
#   <matplotlib.axis.XTick at 0x7fc982a5a7f0>,
#   <matplotlib.axis.XTick at 0x7fc982a54ac0>,
#   <matplotlib.axis.XTick at 0x7fc982a4b2b0>,
#   <matplotlib.axis.XTick at 0x7fc982a5ac10>,
#   <matplotlib.axis.XTick at 0x7fc982a5aeb0>,
#   <matplotlib.axis.XTick at 0x7fc982a60400>,
#   <matplotlib.axis.XTick at 0x7fc982a60910>,
#   <matplotlib.axis.XTick at 0x7fc982a60e20>,
#   <matplotlib.axis.XTick at 0x7fc982a67370>,
#   <matplotlib.axis.XTick at 0x7fc982a67880>],
#  [Text(0.4, 0, 'Alaska'),
#   Text(1.4, 0, 'Alabama'),
#   Text(2.4, 0, 'Arkansas'),
#   Text(3.4, 0, 'Arizona'),
#   Text(4.4, 0, 'California'),
#   Text(5.4, 0, 'Colorado'),
#   Text(6.4, 0, 'Connecticut'),
#   Text(7.4, 0, 'Delaware'),
#   Text(8.4, 0, 'Florida'),
#   Text(9.4, 0, 'Georgia'),
#   Text(10.4, 0, 'Hawaii'),
#   Text(11.4, 0, 'Iowa'),
#   Text(12.4, 0, 'Idaho'),
#   Text(13.4, 0, 'Illinois'),
#   Text(14.4, 0, 'Indiana'),
#   Text(15.4, 0, 'Kansas'),
#   Text(16.4, 0, 'Kentucky'),
#   Text(17.4, 0, 'Louisiana'),
#   Text(18.4, 0, 'Massachusetts'),
#   Text(19.4, 0, 'Maryland'),
#   Text(20.4, 0, 'Maine'),
#   Text(21.4, 0, 'Michigan'),
#   Text(22.4, 0, 'Minnesota'),
#   Text(23.4, 0, 'Missouri'),
#   Text(24.4, 0, 'Mississippi'),
#   Text(25.4, 0, 'Montana'),
#   Text(26.4, 0, 'North Carolina'),
#   Text(27.4, 0, 'North Dakota'),
#   Text(28.4, 0, 'Nebraska'),
#   Text(29.4, 0, 'New Hampshire'),
#   Text(30.4, 0, 'New Jersey'),
#   Text(31.4, 0, 'New Mexico'),
#   Text(32.4, 0, 'Nevada'),
#   Text(33.4, 0, 'New York'),
#   Text(34.4, 0, 'Ohio'),
#   Text(35.4, 0, 'Oklahoma'),
#   Text(36.4, 0, 'Oregon'),
#   Text(37.4, 0, 'Pennsylvania'),
#   Text(38.4, 0, 'Rhode Island'),
#   Text(39.4, 0, 'South Carolina'),
#   Text(40.4, 0, 'South Dakota'),
#   Text(41.4, 0, 'Tennessee'),
#   Text(42.4, 0, 'Texas'),
#   Text(43.4, 0, 'Utah'),
#   Text(44.4, 0, 'Virginia'),
#   Text(45.4, 0, 'Vermont'),
#   Text(46.4, 0, 'Washington'),
#   Text(47.4, 0, 'Wisconsin'),
#   Text(48.4, 0, 'West Virginia'),
#   Text(49.4, 0, 'Wyoming')])

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0.0, 71.1)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
